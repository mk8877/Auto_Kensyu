# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import datetime
import os
import webbrowser
import pandas as pd

# use creds to create a client to interact with the Google Drive API 認証情報
scope = ['https://spreadsheets.google.com/feeds'] #google spreadsheet のAPI
creds = ServiceAccountCredentials.from_json_keyfile_name('spread-sheet-386510-6b8a91b72e28.json', scope) #秘密鍵json file名
client = gspread.authorize(creds) #authenticate with Google  

# spreadsheatを指定してsheet1を開く
spreadsheet_id = '1Lo2XlNUG97LDFjjugDh1CRPDEWzp8x-AlYaECOIRRXE'  # Please set your Google Sheets ID
sheet = client.open_by_key(spreadsheet_id).sheet1

# 今日の日付を取得(YY/MM/DD形式)
today = datetime.date.today().strftime("%Y/%m/%d")

#全ての行を取得
rows = sheet.get_all_values()


# J列とK列が空白である行を保存するリスト
empty_rows = []
# 各行をループし、J列とK列が空白である行のA列の内容とその行番号を保存
for i, row in enumerate(rows, start=1):  #rowはある行を1D配列として格納したもの.
    if not row[9] or not row[10]:  # 列は0から始まるので、J列とK列はそれぞれ9と10
        empty_rows.append((i, row))


# 空白の行を一覧表示
empty_rowlist = []
index_list = []
for row_num, row in empty_rows:
    dummy = row
    empty_rowlist.append(dummy)
    index_list.append(row_num)

columns_index = pd.DataFrame(empty_rowlist,index = index_list,columns=['通称', '型番', 'Web', '予算管理者', '使用者', '単価', '数量', '合計', '発注日', '納品日', '伝票処理日', '定価'])
columns_index
# Out:
#                     通称         型番
# 2     ネオジム磁石Φ20x50(mm)      NO481  \
# 3     Silson社製SiNメンブレン
# 4        minus-k 除振台修理    125BM-8
# 5          ソーラボ回転ステージ等  CRM1PT/M他
# 6   シグマ光機2軸ステージコントローラー   SHOT-702
# 17              メタルマスク
# 21             BNCコネクタ      BNCB2
# 22             ビームブロック      LB1/M
# 23                 ポスト  TR75/M-JP
# 24         M5ネジ(30 mm)
# 25         M5ネジ(35 mm)
#
#                                                   Web 予算管理者  使用者        単価
# 2   https://www.neomag.jp/shop/shoppingcart/itemde...         水野    ¥5,692  \
# 3                                                        山田   山田   ¥15,620
# 4                                                        成島   成島  ¥358,958
# 5                                                        成島   成島  ¥239,930
# 6                                                        山田   山田  ¥156,750
# 17                     http://www.mitani-micro.co.jp/    山田   山田   ¥33,000
# 21  https://www.thorlabs.co.jp/thorproduct.cfm?par...    佐藤   宗片    ¥4,316
# 22  https://www.thorlabs.co.jp/thorproduct.cfm?par...    佐藤         ¥7,898
# 23  https://www.thorlabs.co.jp/thorproduct.cfm?par...    佐藤           ¥843
# 24              https://www.monotaro.com/p/2901/8317/    山田   望月      ¥802
# 25              https://www.monotaro.com/p/2901/8326/    山田  　望月      ¥802
#
#     数量        合計     発注日       納品日 伝票処理日             定価
# 2    1    ¥5,692
# 3   25  ¥390,500  230410                   \14,200 (税抜)
# 4    1  ¥358,958  230410
# 5    1  ¥239,930  230410  4/11(一部)
# 6    2  ¥313,500  230412    230418        \142,500 (税抜)
# 17   2   ¥66,000  230427
# 21   2    ¥8,632  230501                    \4,316 (税抜)
# 22   2   ¥15,796  230501                    \7,898 (税抜)
# 23   2    ¥1,686  230501                      \843 (税抜)
# 24   1      ¥802  230502
# 25   1      ¥802  230502

# %%
for i, row in enumerate(rows, start=1):  #全ての行について
    if not row[9] or not row[10]:  # 列は0から始まるので、J列(納品日）とK列（伝票処理日）はそれぞれ9と10
        print(f'Row number: {i}, Name: {row[0]}')

        # ユーザーに入力を求める
        print('Would you like to write today\'s date to column J, K or both? (Enter "J", "K", "both" or "none")')
        choice = input()

        # 選択に応じて日付を書き込む
        if choice.lower() == 'j':
            sheet.update_cell(i, 10, today)  # J列
        elif choice.lower() == 'k':
            sheet.update_cell(i, 11, today)  # K列
        elif choice.lower() == 'both':
            sheet.update_cell(i, 10, today)  # J列
            sheet.update_cell(i, 11, today)  # K列


#open spread sheet
webbrowser.open('https://docs.google.com/spreadsheets/d/1Lo2XlNUG97LDFjjugDh1CRPDEWzp8x-AlYaECOIRRXE/edit')
# Out:
# Row number: 2, Name: ネオジム磁石Φ20x50(mm)
# Would you like to write today's date to column J, K or both? (Enter "J", "K", "both" or "none")
